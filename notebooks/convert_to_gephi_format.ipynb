# %%
import IPython
from pathlib import Path
import pandas as pd
import pickle

notebook_name = "/".join(
        IPython.extract_module_locals()[1]["__vsc_ipynb_file__"].split("/")[-5:]
    )
print(notebook_name)
root_folder = Path(notebook_name).parent.parent
print(root_folder)

data_path = Path(root_folder, "data", "asserters_filtered.pkl")
# read pd.DataFrame from pickle
with open(data_path, "rb") as f:
    data = pd.read_pickle(f)

data.head(10)
# Out:
# d:\projects\aalto\hands_on_networks\patents\notebooks\convert_to_gephi_format.ipynb
# d:\projects\aalto\hands_on_networks\patents
#     case_node_id                                     Case Title  \
# 10        118532                 Fulhorst v. Toyota Motor Corp.
# 24        118541                 Pitney Bowes v. Stamps.Com Inc
# 31        118547  Texas Instruments, et al v. Linear Technology
# 32        118548         Texas Instruments v. Linear Technology
# 33        118549         Natl Instruments v. MathWorks Inc, The
# 34        118549         Natl Instruments v. MathWorks Inc, The
# 37        118552                Paragon Luggage Inc v. Tumi Inc
# 38        118553               Paragon Luggage Inc v. Coach Inc
# 40        118555               Paragon Luggage Inc v. Coach Inc
# 48        118562               Texas Instruments v. Tessera Inc
#
#    Civil Action #     Venue Filing Date  included in random sample  DJ  \
# 10  2:00-cv-00071  E.D.Tex.  2000-04-27                          0   0
# 24  5:00-cv-00262  E.D.Tex.  2000-09-18                          0   0
# 31  2:01-cv-00003  E.D.Tex.  2001-01-06                          0   0
# 32  2:01-cv-00004  E.D.Tex.  2001-01-06                          1   0
# 33  2:01-cv-00011  E.D.Tex.  2001-01-25                          0   0
# 34  2:01-cv-00011  E.D.Tex.  2001-01-25                          0   0
# 37  4:01-cv-00089  E.D.Tex.  2001-03-07                          0   0
# 38  4:01-cv-00090  E.D.Tex.  2001-03-07                          1   0
# 40  4:01-cv-00098  E.D.Tex.  2001-03-15                          0   0
# 48  2:01-cv-00163  E.D.Tex.  2001-08-03                          0   0
#
#                                         patents  \
# 10                                      4523178
# 24                                          NaN
# 31  4471292; 4794277; 4893091; 4906863; 5390069
# 32                    4884674; 5216613; 6039168
# 33           4901221; 4914568; 5291587; 5301336
# 34           4901221; 4914568; 5291587; 5301336
# 37                                          NaN
# 38                                          NaN
# 40                                          NaN
# 48                                          NaN
#
#                   Alleged Infringer  paragraph_id  \
# 10       [Toyota Motor Corporation]          4025
# 24               [Stamps.com, Inc.]          4039
# 31  [Linear Technology Corporation]          4046
# 32  [Linear Technology Corporation]          4047
# 33            [The MathWorks, Inc.]          4048
# 34            [The MathWorks, Inc.]          4049
# 37                     [Tumi, Inc.]          4052
# 38                    [Coach, Inc.]          4053
# 40                    [Coach, Inc.]          4055
# 48                  [Tessera, Inc.]          4063
#
#                      Patent Asserter  asserter_id  Asserter Category  \
# 10                 George E Fulhorst        68571                9.0
# 24                  Pitney Bowes Inc        94702                8.0
# 31    Texas Instruments Incorporated       108803                8.0
# 32    Texas Instruments Incorporated       108803                8.0
# 33  National Instruments Corporation        88748                8.0
# 34  National Instruments Corporation        88748                8.0
# 37               Paragon Luggage Inc        92797                8.0
# 38               Paragon Luggage Inc        92797                8.0
# 40               Paragon Luggage Inc        92797                8.0
# 48    Texas Instruments Incorporated       108803                8.0
#
#    infringet_aliases                        i_aliases  \
# 10          [toyota]                         [toyota]
# 24                []               [Stamps.com, Inc.]
# 31                []  [Linear Technology Corporation]
# 32                []  [Linear Technology Corporation]
# 33                []            [The MathWorks, Inc.]
# 34                []            [The MathWorks, Inc.]
# 37                []                     [Tumi, Inc.]
# 38                []                    [Coach, Inc.]
# 40                []                    [Coach, Inc.]
# 48                []                  [Tessera, Inc.]
#
#                           pa_aliases
# 10                 George E Fulhorst
# 24                  Pitney Bowes Inc
# 31    Texas Instruments Incorporated
# 32    Texas Instruments Incorporated
# 33  National Instruments Corporation
# 34  National Instruments Corporation
# 37               Paragon Luggage Inc
# 38               Paragon Luggage Inc
# 40               Paragon Luggage Inc
# 48    Texas Instruments Incorporated

# %%
# left only data with patent trolls, they have "Asserter Category" == 1 or 4 or 5
trolls = [1., 4., 5]
# find all rows with "Asserter Category" == 1 or 4 or 5
data_trolls = data[data["Asserter Category"].isin(trolls)]
data_trolls["i_date"] = pd.to_datetime(data_trolls["Filing Date"])
print(data.shape)
print(data_trolls.shape)
# Out:
# (44407, 16)
# (19824, 17)
# C:\Users\sWX1288665\AppData\Local\Temp\ipykernel_25640\3998170870.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_trolls["i_date"] = pd.to_datetime(data_trolls["Filing Date"])

# %%
data_trolls
# Out:
#        case_node_id                                         Case Title  \
# 78           118586      Charles E Hill Assoc v. Amazon.com Inc, et al
# 84           118591     IP Innovation LLC, et al v. Dell Computer Corp
# 85           118591     IP Innovation LLC, et al v. Dell Computer Corp
# 86           118592       IAP Intermodal LLC v. AMR Corporation, et al
# 102          118604        Datatreasury Corp v. First Data Corp, et al
# ...             ...                                                ...
# 99455        237356  Typhoon IP LLC v. Alpine Electronics of Americ...
# 99456        237357   Typhoon IP LLC v. Clarion Corporation of America
# 99469        237370   Optical Licensing LLC v. Home Depot U.S.A., Inc.
# 99470        237371  Optical Licensing LLC v. Lowe's Companies, Inc...
# 99473        237373  Rothschild Broadcast Distribution Systems, LLC...
#
#       Civil Action #     Venue Filing Date  included in random sample  DJ  \
# 78     2:02-cv-00186  E.D.Tex.  2002-08-16                          0   0
# 84     2:02-cv-00295  E.D.Tex.  2002-12-09                          0   0
# 85     2:02-cv-00295  E.D.Tex.  2002-12-09                          0   0
# 86     2:02-cv-00310  E.D.Tex.  2002-12-13                          0   0
# 102    5:02-cv-00094  E.D.Tex.  2002-05-02                          0   0
# ...              ...       ...         ...                        ...  ..
# 99455  2:21-cv-04286  S.D.Ohio  2021-08-30                          0   0
# 99456  2:21-cv-04285  S.D.Ohio  2021-08-30                          0   0
# 99469  6:21-cv-00904  W.D.Tex.  2021-08-31                          0   0
# 99470  6:21-cv-00905  W.D.Tex.  2021-08-31                          0   0
# 99473  2:21-cv-04906  E.D.N.Y.  2021-08-31                          0   0
#
#                          patents  \
# 78     5528490; 5761649; 6029142
# 84                       5424780
# 85                       5424780
# 86                           NaN
# 102                          NaN
# ...                          ...
# 99455                        NaN
# 99456                        NaN
# 99469                    6791898
# 99470                    6791898
# 99473                    8856221
#
#                                        Alleged Infringer  paragraph_id  \
# 78     [Quixtar, Inc., L.L. Bean, Inc., The Gap, Inc....          4094
# 84                           [Dell Computer Corporation]          4100
# 85                           [Dell Computer Corporation]          4101
# 86     [American Eagle Airline Inc, AMR Corporation, ...          4102
# 102    [First Data Merchant Services Corporation, Tel...          4120
# ...                                                  ...           ...
# 99455              [Alpine Electronics of America, Inc.]        105365
# 99456                 [Clarion Corporation (of America)]        105366
# 99469                          [Home Depot U.S.A., Inc.]        105383
# 99470  [Lowe's Companies, Inc., Lowe's Home Centers, ...        105384
# 99473                              [Nikon Americas Inc.]        105387
#
#                                       Patent Asserter  asserter_id  \
# 78                 Charles E. Hill & Associates, Inc.        54352
# 84                                  IP Innovation LLC        75483
# 85                   Technology Licensing Corporation       108193
# 86                                 IAP Intermodal LLC        73276
# 102                          Datatreasury Corporation        58934
# ...                                               ...          ...
# 99455                                  Typhoon IP LLC       228786
# 99456                                  Typhoon IP LLC       228786
# 99469                           Optical Licensing LLC       232541
# 99470                           Optical Licensing LLC       232541
# 99473  Rothschild Broadcast Distribution Systems, LLC       100138
#
#        Asserter Category infringet_aliases  \
# 78                   5.0      [amazon.com]
# 84                   1.0            [dell]
# 85                   1.0            [dell]
# 86                   5.0                []
# 102                  5.0                []
# ...                  ...               ...
# 99455                1.0                []
# 99456                1.0                []
# 99469                1.0                []
# 99470                1.0                []
# 99473                5.0                []
#
#                                                i_aliases  \
# 78     [Quixtar, Inc., L.L. Bean, Inc., The Gap, Inc....
# 84                                                [dell]
# 85                                                [dell]
# 86            [AMR Corporation, American Airlines, Inc.]
# 102    [First Data Merchant Services Corporation, Tel...
# ...                                                  ...
# 99455              [Alpine Electronics of America, Inc.]
# 99456                 [Clarion Corporation (of America)]
# 99469                          [Home Depot U.S.A., Inc.]
# 99470  [Lowe's Companies, Inc., Lowe's Home Centers, ...
# 99473                              [Nikon Americas Inc.]
#
#                                            pa_aliases     i_date
# 78                 Charles E. Hill & Associates, Inc. 2002-08-16
# 84                                  IP Innovation LLC 2002-12-09
# 85                   Technology Licensing Corporation 2002-12-09
# 86                                 IAP Intermodal LLC 2002-12-13
# 102                          Datatreasury Corporation 2002-05-02
# ...                                               ...        ...
# 99455                                  Typhoon IP LLC 2021-08-30
# 99456                                  Typhoon IP LLC 2021-08-30
# 99469                           Optical Licensing LLC 2021-08-31
# 99470                           Optical Licensing LLC 2021-08-31
# 99473  Rothschild Broadcast Distribution Systems, LLC 2021-08-31
#
# [19824 rows x 17 columns]

# %%
# prepare gephi data
import numpy as np
def time_interval(date, year_thresholds):
    # convert
    return f"<[{year_thresholds[np.argmin(np.abs(year_thresholds - date.year))]}, {year_thresholds[np.argmin(np.abs(year_thresholds - date.year)) + 1]})>"


def make_gephi_data(df):
    # Extract unique nodes from 'pa_aliases' and 'i_aliases', where 'i_aliases' is a list and 'pa_aliases' is just a string
    pa_aliases = df['pa_aliases'].explode().unique()
    i_aliases = df['i_aliases'].explode().unique()
    nodes = set(list(pa_aliases) + list(i_aliases))
    # binary list of patent trolls (if node is in 'pa_aliases' then it is a patent troll)
    troll_list = [1 if node in pa_aliases else 0 for node in nodes]

    # Create nodes DataFrame
    nodes_df = pd.DataFrame({'Id': range(1, len(nodes) + 1), 'Label': list(nodes), 'Troll': troll_list})

    # convert this to a dictionary for easy lookup
    nodes_dict = dict(zip(nodes_df['Label'], nodes_df['Id']))

    # Define start and end years
    start_year = 2000
    end_year = 2023

    # make 3 years thresholds
    year_thresholds = np.arange(start_year, end_year, 2)

    # Create edges DataFrame
    edges = []
    for _, row in df.iterrows():
        for i_alias in row['i_aliases']:
            # TimeInterval is a list of 2 elements: closest years from year_thresholds
            edges.append({'Source': nodes_dict[row['pa_aliases']], 'Target': nodes_dict[i_alias], 'Type': 'directed', #r'Timeset': row['Filing Date'],
                         'TimeInterval': time_interval(row['i_date'], year_thresholds),'Label': row['Filing Date']})

    edges_df = pd.DataFrame(edges)
    # remove duplicates
    edges_df = edges_df.drop_duplicates()
    # add Id column
    edges_df['Label'] = range(1, len(edges_df) + 1)
    return nodes_df, edges_df

def filter_by_degree(nodes_df, edges_df, min_degree):
    # count degree for each node
    degree = edges_df['Source'].value_counts().add(edges_df['Target'].value_counts(), fill_value=0)
    # filter nodes by degree
    nodes_df_filtered = nodes_df[nodes_df['Id'].isin(degree[degree >= min_degree].index)]
    # remove nodes and edges that are not in nodes_df_filtered
    edges_df_filtered = edges_df[edges_df['Source'].isin(nodes_df_filtered['Id']) & edges_df['Target'].isin(nodes_df_filtered['Id'])]
    #
    return nodes_df_filtered, edges_df_filtered

# %%
n, e = make_gephi_data(data_trolls)
print(n.shape)
print(e.shape)
print(n.head())
print(e.head())
n, e = filter_by_degree(n, e, 10)
print(n.shape)
print(e.shape)
# Save nodes and edges to CSV
n.to_csv(Path(root_folder, "data", 'gephi_nodes_trolls.csv'), index=False)
e.to_csv(Path(root_folder, "data", 'gephi_edges_trolls.csv'), index=False)
# Out:
# (6106, 3)
# (32119, 5)
#    Id                                      Label  Troll
# 0   1                          Capital One, N.A.      0
# 1   2  Fedex Customer Information Services, Inc.      0
# 2   3                            L.L. Bean, Inc.      0
# 3   4                    Black Diamond Equipment      0
# 4   5                Savage Communications Inc.,      0
#    Source  Target      Type    TimeInterval  Label
# 0    1588     946  directed  <[2002, 2004)>      1
# 1    1588       3  directed  <[2002, 2004)>      2
# 2    1588    2362  directed  <[2002, 2004)>      3
# 3    1588    5599  directed  <[2002, 2004)>      4
# 4    1588    1524  directed  <[2002, 2004)>      5
# (1488, 3)
# (16877, 5)

# %%
from collections import Counter

import pandas as pd
import networkx as nx

# function to filter out all asserters with less than threshold count and all infrindgements with less than threshold count
def filter_asserters(data, threshold):
    data_ = data.copy()
    asserters = data_["pa_aliases"]
    # each element in just a string
    count_asserters = Counter(asserters)
    # filter out all asserters with less than threshold count
    asserters = [asserter for asserter in asserters if count_asserters[asserter] >= threshold]
    # remove all rows with pa_aliases not in asserters
    data_ = data_[data_["pa_aliases"].apply(lambda x: x in asserters)]
    infrindgements = [i for l in data_["i_aliases"] for i in l]
    count_infrindgements = Counter(infrindgements)
    # filter out all infrindgements with less than threshold count
    infrindgements = [infrindgement for infrindgement in infrindgements if count_infrindgements[infrindgement] >= threshold]
    # remove all elements in i_aliases not in infrindgements
    data_["i_aliases"] = data_["i_aliases"].apply(lambda x: [i for i in x if i in infrindgements])
    # remove all rows with empty i_aliases
    data_ = data_[data_["i_aliases"].apply(lambda x: len(x) > 0)]
    return data_

def make_years_data(data, start_year, end_year):
    data_2_years = data[data["i_date"].apply(lambda x: x.year < end_year)]
    return data_2_years[data_2_years["i_date"].apply(lambda x: x.year >= start_year)]


def make_network(df, min_degree):
    G = nx.DiGraph()
    for _, row in df.iterrows():
        pa_alias = row['pa_aliases']
        for i_alias in row['i_aliases']:
            if pd.notna(i_alias) and pd.notna(pa_alias):
                # Add nodes
                G.add_node(i_alias)
                G.add_node(pa_alias)
                # Add edge from pa_alias to i_alias
                if G.has_edge(pa_alias, i_alias):
                    G[pa_alias][i_alias]['weight'] += 1
                else:
                    G.add_edge(pa_alias, i_alias, weight=1)
    # Remove nodes with degree less than min_degree
    print(f"Number of nodes before removing nodes with degree less than {min_degree}: {G.number_of_nodes()}")
    G.remove_nodes_from([node for node, degree in dict(G.degree()).items() if degree < min_degree])
    print(f"Number of nodes after removing nodes with degree less than {min_degree}: {G.number_of_nodes()}")
    return G

# %%
import numpy as np

# filter out all asserters with less than 10 count and all infrindgements with less than 10 count
filtered_data = filter_asserters(data, 10)

# %%
# now we want to download the data, filter it and make a network
# we want to make it to use in gephi, so we need to save the network in a file with .gexf extension


# introduce dynamic variables
# You define a single network but add 'start' and 'end' attributes to set when a node/edge appears or vanish.



def make_dynamic_network(df):

    # Assuming 'i_date' is your timestamp column
    df["i_date"] = pd.to_datetime(df["Filing Date"])

    # Define start and end years
    start_year = 2000
    end_year = 2022

    # make 3 years thresholds
    year_thresholds = np.arange(start_year, end_year, 3)

    # iterate over the years, make related data, make network with start and end attributes, add it to the dynamic graph
    main_graph = nx.MultiDiGraph()

    for i in range(len(year_thresholds) - 1):
        start_year = int(year_thresholds[i])
        end_year = int(year_thresholds[i + 1])
        data_2_years = make_years_data(df, start_year, end_year)
        G = make_network(data_2_years, 2)
        for edge in G.edges(data=True):
            main_graph.add_edge(edge[0], edge[1], weight=edge[2]['weight'], start=start_year, end=end_year)

    return main_graph

# %%
# make network and save it to a file
G_ = make_dynamic_network(filtered_data)

# save the network in a file with .gexf extension
network_path = Path(root_folder, "data", "network_th_10_3years.gexf")
# add dynamic attributes to the network
nx.write_gexf(G_, network_path)
# Out:
# Number of nodes before removing nodes with degree less than 2: 409
# Number of nodes after removing nodes with degree less than 2: 250
# Number of nodes before removing nodes with degree less than 2: 590
# Number of nodes after removing nodes with degree less than 2: 390
# Number of nodes before removing nodes with degree less than 2: 912
# Number of nodes after removing nodes with degree less than 2: 645
# Number of nodes before removing nodes with degree less than 2: 1273
# Number of nodes after removing nodes with degree less than 2: 1061
# Number of nodes before removing nodes with degree less than 2: 1556
# Number of nodes after removing nodes with degree less than 2: 1373
# Number of nodes before removing nodes with degree less than 2: 1408
# Number of nodes after removing nodes with degree less than 2: 1190
# Number of nodes before removing nodes with degree less than 2: 1079
# Number of nodes after removing nodes with degree less than 2: 843
